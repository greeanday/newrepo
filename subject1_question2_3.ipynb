# %% [markdown]
# <a href="https://colab.research.google.com/github/greeanday/newrepo/blob/master/subject1_question2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataFrame=pd.read_csv("subject101.dat",sep=" ",header=None)

# %%
dataFrame.shape[1]
# Out:
# 54

# %%
dataFrame.columns=["timestamp","activityID","heart_rate"]+[f'col_{i}' for i in range(4,55)]

# %%
dataFrame["heart_rate"]=pd.to_numeric(dataFrame["heart_rate"], errors="coerce")

# %%
standing=dataFrame[dataFrame["activityID"]==3]["heart_rate"].dropna()
running=dataFrame[dataFrame["activityID"]==5]["heart_rate"].dropna()
jumping=dataFrame[dataFrame["activityID"]==24]["heart_rate"].dropna()

# %%
print("Standing heart rate avarage:", standing.mean())
print("Running heart rate avarage:", running.mean())
print("Rope jumping heart rate avarage:", jumping.mean())
# Out:
# Standing heart rate avarage: 103.42590725806451
# Running heart rate avarage: 161.338485316847
# Rope jumping heart rate avarage: 165.9949152542373

# %%
import pandas as pd
dataFrame=pd.read_csv("subject101.dat",sep=" ",header=None)

dataFrame.columns=["timestamp","activityID","heart_rate"]+[f'col_{i}' for i in range(4,55)]

dataFrame["heart_rate"]=pd.to_numeric(dataFrame["heart_rate"], errors="coerce")

standing=dataFrame[dataFrame["activityID"]==3]["heart_rate"].dropna()
running=dataFrame[dataFrame["activityID"]==5]["heart_rate"].dropna()
jumping=dataFrame[dataFrame["activityID"]==24]["heart_rate"].dropna()

print("Standing heart rate avarage:", standing.mean())
print("Running heart rate avarage:", running.mean())
print("Rope jumping heart rate avarage:", jumping.mean())
# Out:
# Standing heart rate avarage: 103.42590725806451
# Running heart rate avarage: 161.338485316847
# Rope jumping heart rate avarage: 165.9949152542373

# %% [markdown]
# # ✅ ŞİMDİ MAGNİTUDE HESABINA GEÇİYORUZ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataFrame=pd.read_csv("subject101.dat",sep=" ",header=None)

# %%
dataFrame.shape[1]
# Out:
# 54

# %%
dataFrame.columns=["timestamp","activityID","heart_rate"]+[f'col_{i}' for i in range(4,55)]

# %%
dataFrame["col_40"]=pd.to_numeric(dataFrame["col_40"], errors="coerce")
dataFrame["col_41"]=pd.to_numeric(dataFrame["col_41"], errors="coerce")
dataFrame["col_42"]=pd.to_numeric(dataFrame["col_42"], errors="coerce")

# %%
walking=dataFrame[dataFrame["activityID"]==4]

# %%
xyz = walking[["timestamp","col_40", "col_41", "col_42"]].dropna()
# veya xyz = walking[["timestamp","col_40", "col_41", "col_42"]]
#sonra da xyz["col_40", "col_41", "col_42"].dropna()
#eğer zmaan verisinde eksik değr var ama diğerleri tamsa hesaplamayı tamamlayıp zaman verisinden dolayı o satırları kaybetmemek için NaN düşüşünü timestep'e uygulamayabilirsin.

# %%
magnitude = np.sqrt(xyz["col_40"]**2 + xyz["col_41"]**2 + xyz["col_42"]**2)

# %%
print(magnitude)
# Out:
# 223759    9.835221
# 223760    9.869890
# 223761    9.883564
# 223762    9.829694
# 223763    9.834589
#             ...
# 246007    9.861381
# 246008    9.837874
# 246009    9.833071
# 246010    9.877807
# 246011    9.863739
# Length: 22185, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataFrame=pd.read_csv("subject101.dat",sep=" ",header=None)

dataFrame.columns=["timestamp","activityID","heart_rate"]+[f'col_{i}' for i in range(4,55)]


dataFrame["col_40"]=pd.to_numeric(dataFrame["col_40"], errors="coerce")
dataFrame["col_41"]=pd.to_numeric(dataFrame["col_41"], errors="coerce")
dataFrame["col_42"]=pd.to_numeric(dataFrame["col_42"], errors="coerce")

walking=dataFrame[dataFrame["activityID"]==4]

xyz = walking[["timestamp","col_40", "col_41", "col_42"]].dropna()

magnitude = np.sqrt(xyz["col_40"]**2 + xyz["col_41"]**2 + xyz["col_42"]**2)

zaman=xyz["timestamp"]

plt.plot(zaman, magnitude)
plt.title("Yürüyüş Sırasında İvme Büyüklüğü-16g")
plt.xlabel("Zaman (seconds)")
plt.ylabel("Magnitude")
plt.show()

# %%
zaman=xyz["timestamp"]

plt.plot(zaman, magnitude)
plt.title("Yürüyüş Sırasında İvme Büyüklüğü-16g")
plt.xlabel("Zaman (seconds)")
plt.ylabel("Magnitude")
plt.show()

# %%
zaman=xyz["timestamp"]
plt.figure(figsize=(20, 4))
plt.plot(zaman, magnitude)
plt.title("Yürüyüş Sırasında İvme Büyüklüğü-16g")
plt.xlabel("Zaman (seconds)")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# **Gerçekten 140- 150'li veriler var mı diye kontorl etmek için: **
#
# problemli = magnitude[magnitude > 60]
#
# print(problemli)
#
# print("Şüpheli değer sayısı:", len(problemli))
#
# print("Max değer:", np.max(magnitude))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 4))  # genişliği büyük tut → sinyal yayılır

plt.plot(zaman, magnitude)
plt.title("Yürüyüş Sırasında İvme Büyüklüğü")
plt.xlabel("Zaman (saniye)")
plt.ylabel("İvme Büyüklüğü (m/s²)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from google.colab import files

fig, ax = plt.subplots(figsize=(50, 4))  # fig ve ax nesneleri oluşturuluyor
# Veriyi çiz
ax.plot(zaman, magnitude)
ax.set_title("Yürüyüş Sırasında İvme Büyüklüğü")
ax.set_xlabel("Zaman (saniye)")
ax.set_ylabel("İvme Büyüklüğü (m/s²)")
ax.grid(True)

#  Layout'u düzenle
fig.tight_layout()

#  Önce kaydet, sonra göster
fig.savefig("genis_grafik.png", dpi=300)
plt.show()  # Opsiyonel – görmek istersen

#  İndirmek için
files.download("genis_grafik.png")

# %% [markdown]
# # ⏰ **GRAFİK ETKİLEŞİMLİ OLMASI İÇİN**

# %%
pip install plotly

# %%
import plotly.graph_objects as go
fig=go.Figure()
fig.add_trace(go.Scatter(x=zaman, y=magnitude,mode="lines", name="Yürüyüş Sırasında İvme Büyüklüğü-16g" ))

fig.update_layout(title="Yürüyüş Sırasında İvme Büyüklüğü (Etkileşimli)",xaxis_title="Zaman (seconds)", yaxis_title="İvme Büyüklüğü (m/s²)", hovermode= "x unified")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.io as pio
pio.write_html(fig, file="ivme_grafigi.html" , auto_open=True)

#HTML olarak download edip etkileşimli olarak kalması için böyle yazdık. Önce html olarka oluşturduk.

from google.colab import files
files.download('ivme_grafigi.html')

# bu kodla da dosyayı indirdik.

# %% [markdown]
# # İKİNCİ ETKİLEŞİMLİ GÖRSELLEŞTİRME METHODU:

# %%
pip install mplcursors

# %%
import matplotlib.pyplot as plt
import mplcursors

plt.figure(figsize=(20, 4))
plt.plot(zaman, magnitude, label='İvme Büyüklüğü')
plt.xlabel("Zaman (saniye)")
plt.ylabel("İvme Büyüklüğü (m/s²)")
plt.title("Yürüyüş Sırasında İvme Büyüklüğü")
plt.grid(True)
plt.legend()

# Etkileşimli imleç ekle
cursor = mplcursors.cursor(hover=True)
cursor.connect("add", lambda sel: sel.annotation.set_text(
    f"Zaman: {zaman[sel.index]:.2f} s\nİvme: {magnitude[sel.index]:.2f}"))

plt.tight_layout()
plt.show()
